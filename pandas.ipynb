# %% [markdown]
# <a href="https://colab.research.google.com/github/Ticoliro08/GUI.github.io/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Panda

# %%
import pandas as pd

dados_covid = pd.read_excel('/content/HIST_PAINEL_COVIDBR_01jun2020.xlsx')

dados_covid
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 142794  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142795  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# ...

# %%
#       Primeiros dados

dados_covid.head(3)
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-26          9       210147125.0               1           0
# 1  2020-02-27          9       210147125.0               1           0
# 2  2020-02-28          9       210147125.0               1           0
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos
# 0                0            0               NaN                    NaN
# 1                0            0               NaN                    NaN
# 2                0            0               NaN                    NaN

# %%
#       Ultimos dados

dados_covid.tail(3)
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142798  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 142796        Brasília  2020-05-30         22         3015268.0
# 142797        Brasília  2020-05-31         23         3015268.0
# 142798        Brasília  2020-06-01         23         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 142796            9474         752              162            8
# 142797            9780         306              170            8
# 142798           10510         730              171            1
#
#         Recuperadosnovos  emAcompanhamentoNovos
# 142796               NaN                    NaN
# 142797               NaN                    NaN
# ...

# %%
#       Colunas

dados_covid.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos'],
#       dtype='object')

# %%
dados_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142799 entries, 0 to 142798
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   regiao                 142799 non-null  object
#  1   estado                 142702 non-null  object
#  2   municipio              139850 non-null  object
#  3   coduf                  142799 non-null  int64
#  4   codmun                 140536 non-null  float64
#  5   codRegiaoSaude         139850 non-null  float64
#  6   nomeRegiaoSaude        139850 non-null  object
#  7   data                   142799 non-null  object
#  8   semanaEpi              142799 non-null  int64
#  9   populacaoTCU2019       142113 non-null  float64
#  10  casosAcumulado         142799 non-null  int64
#  11  casosNovos             142799 non-null  int64
#  12  obitosAcumulado        142799 non-null  int64
#  13  obitosNovos            142799 non-null  int64
# ...

# %%
#       Selecionar coluna

dados_covid[['regiao','municipio','estado','coduf']].head(10)
# Out:
#    regiao municipio estado  coduf
# 0  Brasil       NaN    NaN     76
# 1  Brasil       NaN    NaN     76
# 2  Brasil       NaN    NaN     76
# 3  Brasil       NaN    NaN     76
# 4  Brasil       NaN    NaN     76
# 5  Brasil       NaN    NaN     76
# 6  Brasil       NaN    NaN     76
# 7  Brasil       NaN    NaN     76
# 8  Brasil       NaN    NaN     76
# 9  Brasil       NaN    NaN     76

# %%
#
dados_covid.isna().sum()
# Out:
# regiao                        0
# estado                       97
# municipio                  2949
# coduf                         0
# codmun                     2263
# codRegiaoSaude             2949
# nomeRegiaoSaude            2949
# data                          0
# semanaEpi                     0
# populacaoTCU2019            686
# casosAcumulado                0
# casosNovos                    0
# obitosAcumulado               0
# obitosNovos                   0
# Recuperadosnovos         142755
# emAcompanhamentoNovos    142755
# dtype: int64

# %%
#       Copiar dados
dados_covid_copy = dados_covid.copy()

# %%
# verificar qnts campos unicos tem

dados_covid_copy['regiao'].unique()
# Out:
# array(['Brasil', 'Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'],
#       dtype=object)

# %%
#     Filtrar dataframe por campo
dados_covid_copy[dados_covid_copy['regiao']=='Nordeste'].head()
# Out:
#        regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 621  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 622  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 623  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 624  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 625  Nordeste     MA       NaN     21     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 621  2020-03-21         12         7075181.0               1           0
# 622  2020-03-22         13         7075181.0               2           1
# 623  2020-03-23         13         7075181.0               2           0
# 624  2020-03-24         13         7075181.0               8           6
# 625  2020-03-25         13         7075181.0               8           0
#
# ...

# %%
#    Filtrar dataframe po uma lista

lista = ['Nordeste','Sudeste']
dados_covid_copy[dados_covid_copy['regiao'].isin(lista)]
# Out:
#           regiao estado     municipio  coduf    codmun  codRegiaoSaude  \
# 621     Nordeste     MA           NaN     21       NaN             NaN
# 622     Nordeste     MA           NaN     21       NaN             NaN
# 623     Nordeste     MA           NaN     21       NaN             NaN
# 624     Nordeste     MA           NaN     21       NaN             NaN
# 625     Nordeste     MA           NaN     21       NaN             NaN
# ...          ...    ...           ...    ...       ...             ...
# 107720   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107721   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107722   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107723   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107724   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados_covid_copy[(dados_covid_copy['regiao'].isin(lista)) & (~dados_covid_copy['codRegiaoSaude'].isnull())]
# Out:
#           regiao estado     municipio  coduf    codmun  codRegiaoSaude  \
# 16061   Nordeste     MA    Açailândia     21  210005.0         21001.0
# 16062   Nordeste     MA    Açailândia     21  210005.0         21001.0
# 16063   Nordeste     MA    Açailândia     21  210005.0         21001.0
# 16064   Nordeste     MA    Açailândia     21  210005.0         21001.0
# 16065   Nordeste     MA    Açailândia     21  210005.0         21001.0
# ...          ...    ...           ...    ...       ...             ...
# 107720   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107721   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107722   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107723   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 107724   Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados_covid_copy['casosAcumulado'][20]
# Out:
# 291

# %%
total_casos = dados_covid_copy.casosNovos.sum()
total_mortes = dados_covid_copy.obitosNovos.sum()

print(f'o numero de casos é {total_casos} e o numero de mortes é {total_mortes}')
# Out:
# o numero de casos é 1572762 e o numero de mortes é 90610

# %%
morte_rate = dados_covid_copy.obitosNovos.sum() / dados_covid_copy.casosNovos.sum()
print('A taxa de mores do Brasil {:.2f} %'.format(morte_rate*100))
# Out:
# A taxa de mores do Brasil 5.76 %

# %%
mais_casos = dados_covid_copy.casosNovos > 100
mais_casos
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 142794     True
# 142795     True
# 142796     True
# 142797     True
# 142798     True
# Name: casosNovos, Length: 142799, dtype: bool

# %%
dados_covid_copy[mais_casos]
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 21            Brasil    NaN       NaN     76       NaN             NaN
# 22            Brasil    NaN       NaN     76       NaN             NaN
# 23            Brasil    NaN       NaN     76       NaN             NaN
# 24            Brasil    NaN       NaN     76       NaN             NaN
# 25            Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 142794  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142795  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142798  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados_covid_copy['taxa_morte'] = dados_covid_copy['obitosNovos'] / dados_covid_copy['casosNovos']
dados_covid_copy[['obitosNovos','casosNovos','taxa_morte']]
# Out:
#         obitosNovos  casosNovos  taxa_morte
# 0                 0           0         NaN
# 1                 0           0         NaN
# 2                 0           0         NaN
# 3                 0           1    0.000000
# 4                 0           0         NaN
# ...             ...         ...         ...
# 142794            9         539    0.016698
# 142795           12         422    0.028436
# 142796            8         752    0.010638
# 142797            8         306    0.026144
# 142798            1         730    0.001370
#
# [142799 rows x 3 columns]

# %%
dados_covid_copy.drop(columns=['taxa_morte'], inplace=True)

dados_covid_copy.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos'],
#       dtype='object')

# %%
dados_covid_copy.sort_values('casosNovos',ascending=False).head(5)
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 94  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 93  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 92  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 86  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 91  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#           data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 94  2020-05-30         22       210147125.0          498440       33274
# 93  2020-05-29         22       210147125.0          465166       26928
# 92  2020-05-28         22       210147125.0          438238       26417
# 86  2020-05-22         21       210147125.0          330890       20803
# 91  2020-05-27         22       210147125.0          411821       20599
#
#     obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos
# ...

# %%
dados_covid.isna().sum()
# Out:
# regiao                        0
# estado                       97
# municipio                  2949
# coduf                         0
# codmun                     2263
# codRegiaoSaude             2949
# nomeRegiaoSaude            2949
# data                          0
# semanaEpi                     0
# populacaoTCU2019            686
# casosAcumulado                0
# casosNovos                    0
# obitosAcumulado               0
# obitosNovos                   0
# Recuperadosnovos         142755
# emAcompanhamentoNovos    142755
# dtype: int64

# %%
dados_covid_copy.dropna
# Out:
# <bound method DataFrame.dropna of               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 142794  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142795  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142798  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
import numpy as np
import pandas as pd

exame = {'Nome': ['Manuela','Julio','Raul','Paulo'],
         'Nota': [12.5, np.nan, 9, 4.5],
         'Tentativas': [1,1,3,2,],
         'Passou': ['sim','não','sim','não']}
dt = pd.DataFrame(exame)
dt
# Out:
#       Nome  Nota  Tentativas Passou
# 0  Manuela  12.5           1    sim
# 1    Julio   NaN           1    não
# 2     Raul   9.0           3    sim
# 3    Paulo   4.5           2    não

# %%
dados_covid_copy.data
# Out:
# 0         2020-02-26
# 1         2020-02-27
# 2         2020-02-28
# 3         2020-02-29
# 4         2020-03-01
#              ...
# 142794    2020-05-28
# 142795    2020-05-29
# 142796    2020-05-30
# 142797    2020-05-31
# 142798    2020-06-01
# Name: data, Length: 142799, dtype: object

# %%
dados_covid_copy['data'] = pd.to_datetime(dados_covid_copy.data)

dados_covid_copy.data
# Out:
# 0        2020-02-26
# 1        2020-02-27
# 2        2020-02-28
# 3        2020-02-29
# 4        2020-03-01
#             ...
# 142794   2020-05-28
# 142795   2020-05-29
# 142796   2020-05-30
# 142797   2020-05-31
# 142798   2020-06-01
# Name: data, Length: 142799, dtype: datetime64[ns]

# %%
dados_covid_copy['ano'] = pd.DatetimeIndex(dados_covid_copy.data).year
dados_covid_copy['mes'] = pd.DatetimeIndex(dados_covid_copy.data).month
dados_covid_copy['dia'] = pd.DatetimeIndex(dados_covid_copy.data).day
dados_covid_copy['dia_da_semana'] = pd.DatetimeIndex(dados_covid_copy.data).weekday

# %%
dados_covid_copy[['data','ano','mes','dia','dia_da_semana']].head()
# Out:
#         data   ano  mes  dia  dia_da_semana
# 0 2020-02-26  2020    2   26              2
# 1 2020-02-27  2020    2   27              3
# 2 2020-02-28  2020    2   28              4
# 3 2020-02-29  2020    2   29              5
# 4 2020-03-01  2020    3    1              6

# %%
import pandas as pd

funcionario = pd.read_csv('/content/profissao.csv',sep=';')
profissao = pd.read_csv('/content/funcionario.csv',sep=';')

# %%
funcionario
# Out:
#        Profissao  Id_Cargo
# 0      Professor         1
# 1        Gerente         2
# 2  Desenvolvedor         3
# 3       Analista         4

# %%
profissao
# Out:
#       Nome  Id_Cargo
# 0    julia         1
# 1  willian         1
# 2    paulo         2
# 3     ruan         3
# 4    maria         3
# 5  roberto         4

# %%
merged_df = funcionario.merge(profissao, on='Id_Cargo')

# %%
merged_df
# Out:
#        Profissao  Id_Cargo     Nome
# 0      Professor         1    julia
# 1      Professor         1  willian
# 2        Gerente         2    paulo
# 3  Desenvolvedor         3     ruan
# 4  Desenvolvedor         3    maria
# 5       Analista         4  roberto
